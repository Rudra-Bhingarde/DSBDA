# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('heart.csv')
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     60    1   3     145   233    1        0       150     0      2.3    0
# 1     35    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     55    1   1     120   236    0        1       178     0      0.8    2
# 4     56    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 284   60    1   0     140   207    0        0       138     1      1.9    2
# 285   46    1   0     140   311    0        1       120     1      1.8    1
# 286   59    1   3     134   204    0        1       162     0      0.8    2
# 287   54    1   1     154   232    0        0       164     0      0.0    2
# 288   53    1   0     110   335    0        1       143     1      3.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 284    1      3       0
# 285    2      3       0
# 286    2      2       0
# 287    1      2       0
# 288    1      3       0
#
# [289 rows x 14 columns]

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(), annot=True,cmap="Blues")
plt.title("Correlation Heatmap - Heart Dataset")
plt.show()

# %%
plt.figure(figsize=(3,2))
plt.scatter(data['age'],data.iloc[:,3])

# %%
plt.figure(figsize=(3,2))
plt.scatter(data['age'],data.iloc[:,4])

# %%
plt.figure(figsize=(3,2))
plt.scatter(data['age'],data.iloc[:,7])

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='output', data=data)
# Out:
# <Axes: xlabel='output', ylabel='count'>

# %%
plt.figure(figsize=(10,9))
sns.countplot(x='age', data=data)
# Out:
# <Axes: xlabel='age', ylabel='count'>
